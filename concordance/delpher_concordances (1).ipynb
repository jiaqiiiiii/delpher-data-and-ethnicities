# %%
import pandas as pd

seventeenth_contexts = pd.read_csv('/Users/zhujiaqi/Downloads/1600_unique_contexts_by_word.csv')

seventeenth_contexts
# Out:
# /var/folders/5g/vgjq024s5fgc9pf2fchw5m6c0000gn/T/ipykernel_415/1358407541.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#            word                                            context  year  \
# 0    inboorling  waerts haer Bagagie nevens die van andere Perf...  1689
# 1    inboorling  ; wcrwaerts haer Bagagie nevens die van andere...  1689
# 2    inboorling  de Jser op foo wjerdige Perlbnen , om'teenen't...  1683
# 3    inboorling  de Convocatie in deefe ftad fullen mogen wej f...  1696
# 4    inboorling  doen.' Dc Belegerde waren 700 Soldarten fterek...  1685
# ..          ...                                                ...   ...
# 203       moren  eg gekfleld , en aldaer gelukkig binnen gebrag...  1694
# 204       moren  na deßrander ter onder* vraging derOnder-Offic...  1693
# 205       moren  mt'chttiïtètGequeiflenquain bekennen 'iOtA&Z e...  1692
# 206       moren  b' eerste / dcwdcke dus weder crijdirert shnöc...  1645
# 207       moren  Antwerpen naer Cculen,Limburg aen deLaen,Franc...  1697
#
#                                              file_path original_token
# 0    /data/groups/trifecta/jiaqiz/downloaded_zip_de...     Inboorling
# 1    /data/groups/trifecta/jiaqiz/downloaded_zip_de...     Inboorling
# 2    /data/groups/trifecta/jiaqiz/downloaded_zip_de...    Inboorling,
# 3    /data/groups/trifecta/jiaqiz/downloaded_zip_de...     inboorling
# 4    /data/groups/trifecta/jiaqiz/downloaded_zip_de...     Inboorling
# ..                                                 ...            ...
# 203  /data/groups/trifecta/jiaqiz/downloaded_zip_de...          moren
# 204  /data/groups/trifecta/jiaqiz/downloaded_zip_de...          Moren
# 205  /data/groups/trifecta/jiaqiz/downloaded_zip_de...         mor&en
# 206  /data/groups/trifecta/jiaqiz/downloaded_zip_de...          moren
# 207  /data/groups/trifecta/jiaqiz/downloaded_zip_de...         Moren.
#
# [208 rows x 5 columns]

# %%
eighteenth_contexts = pd.read_csv('/Users/zhujiaqi/Downloads/1700_unique_contexts_by_word.csv')

eighteenth_contexts
# Out:
#             word                                            context  year  \
# 0     inboorling  van Sici!ic« b' ponh-'ii , lchccn te willen ft...  1731
# 1     inboorling  ITALIEN. NApels den 14 Augufti. De Vicerby gae...  1731
# 2     inboorling  ..eden ij July. Zondag-morgen pafleetde doot d...  1732
# 3     inboorling  koetfen met s paerden , te gemoet gezonden , e...  1732
# 4     inboorling  in de Conftitutie behoorde te ftellen , dat he...  1736
# ...          ...                                                ...   ...
# 4213       moren  genaamtd JtHaa» , byna nog nieuw, met.zvn Huyz...  1762
# 4214       moren  en folie Jolles Laurensz., Makelaars, zullen o...  1762
# 4215       moren  als HC*OY LANDEN, gelegen zo buytenck Veenderv...  1762
# 4216       moren  S al. Vn jtrmtmnfeM, vetko;pen agtfi.hoone Z a...  1762
# 4217       moren  van Eigendom en VeiLCoi!«.iüitn zullen yier da...  1762
#
#                                               file_path original_token
# 0     /data/groups/trifecta/jiaqiz/downloaded_zip_de...     Inboorling
# 1     /data/groups/trifecta/jiaqiz/downloaded_zip_de...     Inboorling
# 2     /data/groups/trifecta/jiaqiz/downloaded_zip_de...    inboorling,
# 3     /data/groups/trifecta/jiaqiz/downloaded_zip_de...     inboorling
# 4     /data/groups/trifecta/jiaqiz/downloaded_zip_de...    inboorling,
# ...                                                 ...            ...
# 4213  /data/groups/trifecta/jiaqiz/downloaded_zip_de...        Mor-en,
# 4214  /data/groups/trifecta/jiaqiz/downloaded_zip_de...         mor?en
# 4215  /data/groups/trifecta/jiaqiz/downloaded_zip_de...          Moren
# 4216  /data/groups/trifecta/jiaqiz/downloaded_zip_de...        mor?en«
# 4217  /data/groups/trifecta/jiaqiz/downloaded_zip_de...         Moren®
#
# [4218 rows x 5 columns]

# %%
nineteenth_contexts = pd.read_csv('/Users/zhujiaqi/Downloads/1800_unique_contexts_by_word.csv')

nineteenth_contexts
# Out:
#              word                                            context  year  \
# 0      inboorling  geteelde koffie tegen ,en prijs dien het Gouve...  1879
# 1      inboorling  fOOJÏ Geschiedenis f OOK l^i.^derWaldenzenl^»^...  1879
# 2      inboorling  niet, anders zou die hem uit den mond van een ...  1879
# 3      inboorling  der handeling betreft, boven het genoemde stuk...  1879
# 4      inboorling  éea enkel sober maal per dag. Zou men nu ook n...  1879
# ...           ...                                                ...   ...
# 31162       moren  verwijderde zich J. de J., ko- Perslager alhie...  1854
# 31163       moren  van dit ongelukkig land, rijkelijk vergoed wor...  1854
# 31164       moren  uitgeklaard Fossina Siers, K. S. Boiten. Rouaa...  1854
# 31165       moren  Hollandsche Crushed zijn afgedaan 120 V. 110 t...  1854
# 31166       moren  par le R. P. Prat , de Ia Comp. de Jesus. 3 vo...  1854
#
#                                                file_path original_token
# 0      /data/groups/trifecta/jiaqiz/downloaded_zip_de...     inboorling
# 1      /data/groups/trifecta/jiaqiz/downloaded_zip_de...     inboorling
# 2      /data/groups/trifecta/jiaqiz/downloaded_zip_de...     inboorling
# 3      /data/groups/trifecta/jiaqiz/downloaded_zip_de...     inboorling
# 4      /data/groups/trifecta/jiaqiz/downloaded_zip_de...     inboorling
# ...                                                  ...            ...
# 31162  /data/groups/trifecta/jiaqiz/downloaded_zip_de...        mor-?en
# 31163  /data/groups/trifecta/jiaqiz/downloaded_zip_de...        «moren.
# 31164  /data/groups/trifecta/jiaqiz/downloaded_zip_de...         mor»en
# 31165  /data/groups/trifecta/jiaqiz/downloaded_zip_de...          Moren
# 31166  /data/groups/trifecta/jiaqiz/downloaded_zip_de...          moren
#
# [31167 rows x 5 columns]

# %%
import pandas as pd
import nltk
from nltk.text import Text
from nltk.tokenize import word_tokenize
import re
from collections import defaultdict

# Download required NLTK data
nltk.download('punkt', quiet=True)

# Define the target words
target_words = ['moor', 'moren', 'inboorling', 'inboorlingen']

def clean_text(text):
    """Clean and normalize text for better tokenization"""
    if pd.isna(text):
        return ""
    # Remove extra whitespace and normalize
    text = re.sub(r'\s+', ' ', str(text).strip())
    return text

def create_concordance_for_word(word, df):
    """Create NLTK concordance for a specific word"""
    print(f"\n{'='*60}")
    print(f"CONCORDANCE ANALYSIS FOR: {word.upper()}")
    print(f"{'='*60}")
    
    # Filter data for the specific word
    word_data = df[df['word'].str.lower() == word.lower()].copy()
    
    if word_data.empty:
        print(f"No data found for word: {word}")
        return
    
    print(f"Found {len(word_data)} contexts for '{word}'")
    
    # Combine all contexts into one large text
    all_contexts = []
    for context in word_data['context']:
        cleaned_context = clean_text(context)
        if cleaned_context:
            all_contexts.append(cleaned_context)
    
    if not all_contexts:
        print(f"No valid contexts found for '{word}'")
        return
    
    # Join all contexts
    combined_text = ' '.join(all_contexts)
    
    # Tokenize the text
    tokens = word_tokenize(combined_text.lower())
    
    # Create NLTK Text object
    nltk_text = Text(tokens)
    
    # Generate concordance
    print(f"\nConcordance for '{word}' (showing up to 25 lines):")
    print("-" * 80)
    
    try:
        # NLTK concordance
        nltk_text.concordance(word.lower(), lines=25, width=80)
        
        # Additional statistics
        word_count = tokens.count(word.lower())
        total_tokens = len(tokens)
        
        print(f"\nSTATISTICS:")
        print(f"Word frequency: {word_count}")
        print(f"Total tokens in corpus: {total_tokens}")
        print(f"Relative frequency: {word_count/total_tokens:.6f}")
        
        # Year distribution
        if 'year' in word_data.columns:
            year_dist = word_data['year'].value_counts().sort_index()
            print(f"\nYear distribution:")
            for year, count in year_dist.head(10).items():
                print(f"  {year}: {count} occurrences")
    
    except Exception as e:
        print(f"Error generating concordance: {e}")

def analyze_all_words(df, words):
    """Run concordance analysis for all target words"""
    print("NLTK CONCORDANCE ANALYSIS")
    print("=" * 80)
    print(f"Dataset: {len(df)} total contexts")
    print(f"Analyzing words: {', '.join(words)}")
    
    # Summary statistics
    word_counts = {}
    for word in words:
        count = len(df[df['word'].str.lower() == word.lower()])
        word_counts[word] = count
    
    print(f"\nWord frequency summary:")
    for word, count in word_counts.items():
        print(f"  {word}: {count} contexts")
    
    # Generate concordances for each word
    for word in words:
        create_concordance_for_word(word, df)

def create_combined_concordance(df, words):
    """Create a combined concordance for all target words"""
    print(f"\n{'='*60}")
    print("COMBINED CONCORDANCE FOR ALL TARGET WORDS")
    print(f"{'='*60}")
    
    # Filter for all target words
    combined_data = df[df['word'].str.lower().isin([w.lower() for w in words])].copy()
    
    if combined_data.empty:
        print("No data found for any target words")
        return
    
    # Combine all contexts
    all_contexts = []
    for context in combined_data['context']:
        cleaned_context = clean_text(context)
        if cleaned_context:
            all_contexts.append(cleaned_context)
    
    combined_text = ' '.join(all_contexts)
    tokens = word_tokenize(combined_text.lower())
    nltk_text = Text(tokens)
    
    # Show concordance for each word in the combined corpus
    for word in words:
        if word.lower() in tokens:
            print(f"\n--- {word.upper()} in combined corpus ---")
            nltk_text.concordance(word.lower(), lines=10, width=80)

# Main execution
if __name__ == "__main__":
    try:
        # Run individual word analysis
        analyze_all_words(seventeenth_contexts, target_words)
        
        # Run combined analysis
        create_combined_concordance(seventeenth_contexts, target_words)
        
        print(f"\n{'='*80}")
        print("ANALYSIS COMPLETE")
        print(f"{'='*80}")
        
    except Exception as e:
        print(f"Error running analysis: {e}")
        print("Please check your file path and data format.")
# Out:
# NLTK CONCORDANCE ANALYSIS
# ================================================================================
# Dataset: 208 total contexts
# Analyzing words: moor, moren, inboorling, inboorlingen
#
# Word frequency summary:
#   moor: 76 contexts
#   moren: 95 contexts
#   inboorling: 9 contexts
#   inboorlingen: 28 contexts
#
# ============================================================
# CONCORDANCE ANALYSIS FOR: MOOR
# ============================================================
# Found 76 contexts for 'moor'
#
# Concordance for 'moor' (showing up to 25 lines):
# --------------------------------------------------------------------------------
# Displaying 25 of 76 matches:
#  de locge print , capit , gijsbert de moor , utet geüicke lsdinge '' j « kdea ,
# b % lvrr , neaf # 4envar.hen ; ' ; de moor genomen. , » fooal , hy demoor mfende
# e oetroy opden 1 o september lactft , moor hare hoog mog.de heercnsraten ccncrac
# t de j-uüina.ca'piteyn paflcliie ? de moor » lal van daer de poft op madrid « er
# yete krieken beroof 1 , en vetfeheyde moor jen g jjej1 ! ! voorlede vvoerrfdaeh
# royde wel uyt , 'dat de vlim ook door moor t- bi aoders acageftoke * foudi aija
# er turck vöor iso'realen ende yde * . moor voor 10 : . realen mllén moeten rel'a
#  deycrklaert j ( , 't schip de fwatte moor ; ' capitey n \ tmlliain chegjecnllsn
# ud < n aldaer geauiveert ia } idit de moor en haer niet vér van de stadi vef , o
#  * man , s . pacfcet.x-.vérdoes , j . moor , j.frofer , f.vifch « r , lï.steenhg
# rc « ur-pnn » , gekleetxi » ndein wit moor , isjnde onder een ver^melfel , bet «
# r-prios , geklect * • ! « « > ■ . wit moor , is jn de dom-kerck gedoogt onder ee
#  , oediagen wiert : de major , meteen moor aen yder fyde van ( ïin paerr.met wit
#  schipper pietcr verdieften willem de moor , alle geladen met granen per liflabo
# cks vee weg-gevoert hadden , op ha.er moor volgden > ly waren eveu in het te rug
# ours der dragonders , d * r onder een moor ; « arriveert zijn , verneemt , ftaet
#  , de brigadiereaikei en de colloncls moor » baggot en'morgan de namen noch niet
# met ernft voort ; een poftillon , een moor ende één andere lackey wérden in'dé c
# mét ernft voort : ben poftillon , een moor eride een andere lackey werden in dé
# dawlif h , eiq ; joiin , alias robcrt moor , van haychurch * : , wil- - ji.ua wa
# machaey , root en fwart : i lap fwart moor > en een donckrr couleurde moor . die
# fwart moor > en een donckrr couleurde moor . die dcfe góederen voorkomt , relict
#  hentun.cornelis carftens cn jooft de moor . den 13 , pjetér janfz ! poeit , plo
# t eylandt st. mugariet ; d eene , een moor , lalreerde gg > inaer d andere wiert
# r ingebracht en rapporteerde , dat de moor brieven van den commandant aen d < :
#
# STATISTICS:
# Word frequency: 76
# Total tokens in corpus: 10033
# Relative frequency: 0.007575
#
# Year distribution:
#   1645: 1 occurrences
#   1666: 2 occurrences
#   1669: 1 occurrences
#   1670: 3 occurrences
#   1671: 2 occurrences
#   1672: 1 occurrences
#   1673: 1 occurrences
#   1674: 3 occurrences
#   1675: 2 occurrences
#   1677: 3 occurrences
#
# ============================================================
# CONCORDANCE ANALYSIS FOR: MOREN
# ============================================================
# Found 95 contexts for 'moren'
#
# Concordance for 'moren' (showing up to 25 lines):
# --------------------------------------------------------------------------------
# Displaying 25 of 79 matches:
# ceic tydioghe uyt li.arbaryen dat de moren 24000 fierek , '- onlanghs orafl opd
# iieuwë oorfdgs-'preparatien , die de moren maecken , fey t fiïemrditiyöfain ''
#  ; cadix-yet'crocken i 1 o ader ; de moren jonde vervallen , iijn i , dbh '' jf
# tn nóch even leer , '' omdat ' fijne moren en forrific-riënniet « a viljleehtcj
#  adn-jra'-reyten re rrvertertn en op moren » haïe confcentier met dc hoeren hae
# e van 't overlijden van de regerende moren . napoli di romaiiw d-a 3 ïcbxuary .
# echnical image alto metadata artikel moren . accessible ddd:011226011 : mpeg21
# « thomas smit/zifn door , de kapet , moren , men eu tot oftende opgebracht , y
#  algierflè ' kaper opgebracht met 70 moren , welcke verhaelt hekben , dat de al
#  . itvt africa verftaet men , dat de moren la rachc ivel bemachtigt hebben j ma
# . 11 vt africa verftaet men , dat de moren la raclie « el bemachtigt j hebben ;
# rèën ' ; vih ' * z.iléë 'piet , ; 38 moren en twee ' ! steen-ftuckëh ' , datnï
# hier gëjrriveert met tyding , dat de moren liair iij 't gelicht van dc stad oml
#  ortftl n « ft. > « np ding , dat de moren , fóo het ichynt , ; haér tot dè'bel
# anen andere plaetfen in atnca dat de moren fich adaerbcvinncn te bewegen , en d
# een rover van thunis genomen , en 17 moren daer od eevonden heefir . eenen jofe
# ilièn'aaiibaliadeur en de gddic & tc moren , tegeus onie gevangenen gewiitclt ,
# n , 't schip tot pharo verkocht ende moren mede na vranckrijclcgevocrt : tot ph
# , na mallaga , om de gcrantfoeneerde moren af te halen en nauarbaryen te voeren
# den ; gelijck . ••k tuffen haer hö : moren dczeeufle gedeputeerden . de gen efe
# n zalee , alwaer het de vrede met de moren tot conteriteineiit geadiufteert en
#  dte fortres ♦ geinformeett , dat de moren op de creolen cair , peerden , een g
# u afgeoaen en fullen dtfelbegacn até moren . we tijdinge ban candia/ dat o'onfr
# v lèheydé ccopmarifertappëri.met'.ti moren . ' men is hier pajaraieeft doofde r
# waieo , '' ben'mareiciiat vaa moot : moren ei heeft alleen eenige troupen nae '
#
# STATISTICS:
# Word frequency: 79
# Total tokens in corpus: 11303
# Relative frequency: 0.006989
#
# Year distribution:
#   1643: 1 occurrences
#   1645: 1 occurrences
#   1662: 1 occurrences
#   1667: 1 occurrences
#   1669: 2 occurrences
#   1670: 1 occurrences
#   1672: 1 occurrences
#   1673: 3 occurrences
#   1674: 3 occurrences
#   1675: 1 occurrences
#
# ============================================================
# CONCORDANCE ANALYSIS FOR: INBOORLING
# ============================================================
# Found 9 contexts for 'inboorling'
#
# Concordance for 'inboorling' (showing up to 25 lines):
# --------------------------------------------------------------------------------
# Displaying 9 of 9 matches:
#  den collonel van rotkirchea , een inboorling defer stad cn altijt dc kroon vran
#  den collonel van rotkirchea , een inboorling defer stad en altijt de kroon vran
# ns gtotyc van dencmarcken een vrye inboorling , van en » gdandt te maecken ; * e
# e fal eyfehen ; dat geen piadus of inboorling verkooren worde ; en dat de elecïi
#  500. uytn\aeckten . ali aga , een inboorling dts laats en goet sol « act » ' wa
# t hjr genaturalifeert is , als een inboorling gdiaadelr . van daer waren de sold
#  geven . 12. het poolfch recht van inboorling , dat aen de saxifche familie gege
# oor reden , dat den bifl'chop geen inboorling van hec rijck en een van defiüfs b
# genomen en herwaerts ovèrgevoert : inboorling van dit eylant , hecfü » et raaer
#
# STATISTICS:
# Word frequency: 9
# Total tokens in corpus: 1029
# Relative frequency: 0.008746
#
# Year distribution:
#   1683: 1 occurrences
#   1685: 2 occurrences
#   1689: 2 occurrences
#   1696: 1 occurrences
#   1697: 1 occurrences
#   1698: 1 occurrences
#   1699: 1 occurrences
#
# ============================================================
# CONCORDANCE ANALYSIS FOR: INBOORLINGEN
# ============================================================
# Found 28 contexts for 'inboorlingen'
#
# Concordance for 'inboorlingen' (showing up to 25 lines):
# --------------------------------------------------------------------------------
# Displaying 25 of 28 matches:
# rmilfie bekomen , om , ge- wo a 6 inboorlingen , hier te mogen blijven woonen .
# hoeden , wel weder ycmandvan hare inboorlingen tot konirwi mochten kielen , en d
# en gedernouccri i als mede dat de inboorlingen van . ' . 'adagafcar de f ransl-
# nckt , zijn , roor foo `` veel dé inboorlingen aengaet , in waert-gelt aengenomt
# e corrpr-gnk in den oorlog met de inboorlingen v « n't lant te dienen . mt.timoi
# fleten , en fal haer flaet■un met inboorlingen vullen ; f , ifc ' * ' btecnco de
# t foude mogen wereken , ten zv de inboorlingen felf aen 't werek waren . van cam
# n alle -p * paepfche recufinten , inboorlingen ofte-genaturalifccrden , bove « d
# fulks fal fttckken tot nadeel der inboorlingen , waet van'er eengroot gedeelte v
# , alle vremdelingcn , rr.aer geen inboorlingen van defenstaet , hier te mogen la
# e franffe hebben door placcaten d inboorlingen van de conti uyt det.geallieeidcn
# hteiluyden , schuytevocrdeis & c. inboorlingen of gcnaiuralizce.de , tynde tuffc
#  en < lat men eens foo veel eygen inboorlingen met minder koften en meerder gema
# cheppen van eenige brieven , door inboorlingen defes liadts , maer elders haer o
#  werdt gefchrevert , dat aen alle inboorlingen verboden is , na dén ' laetftenfe
# t , uytr > refondert alleen , die inboorlingen zijn . defcn middag heeft den ate
# n vifiteren en de kindersivan d * inboorlingen , voor de vrcmde in employen te p
# cke , die niet nootfakelijck door inboorlingen bekleet moeten werden , fegt men
# inquartiert zijn » dat vericheyde inboorlingen een conliderabel getal vee by den
# dozanea ; '~dls~ rnenfe reets aen inboorlingen verlaten had , geprselenteerr . .
# r 'doganen j 'als menfe reets aen inboorlingen verlaten had , gepratfenteert . '
# fz/gracf- - l/'fchappen , foo wel inboorlingen , als / en van den shcrif/onder l
# enfchen te gelijckv welcke rpeèft inboorlingen ■ zijn eb in vranckrijck moeten b
#  > dochmen hoort biet , dat vecle inboorlingen van dit rijck . gielijck voorheen
#  sondag óchfent vóór het txofen , inboorlingen van curaflou , den hals gebroken
#
# STATISTICS:
# Word frequency: 28
# Total tokens in corpus: 3285
# Relative frequency: 0.008524
#
# Year distribution:
#   1674: 2 occurrences
#   1676: 1 occurrences
#   1683: 1 occurrences
#   1685: 3 occurrences
#   1686: 1 occurrences
#   1687: 3 occurrences
#   1688: 3 occurrences
#   1690: 4 occurrences
#   1691: 2 occurrences
#   1692: 1 occurrences
#
# ============================================================
# COMBINED CONCORDANCE FOR ALL TARGET WORDS
# ============================================================
#
# --- MOOR in combined corpus ---
# Displaying 10 of 76 matches:
#  de locge print , capit , gijsbert de moor , utet geüicke lsdinge '' j « kdea ,
# b % lvrr , neaf # 4envar.hen ; ' ; de moor genomen. , » fooal , hy demoor mfende
# e oetroy opden 1 o september lactft , moor hare hoog mog.de heercnsraten ccncrac
# t de j-uüina.ca'piteyn paflcliie ? de moor » lal van daer de poft op madrid « er
# yete krieken beroof 1 , en vetfeheyde moor jen g jjej1 ! ! voorlede vvoerrfdaeh
# royde wel uyt , 'dat de vlim ook door moor t- bi aoders acageftoke * foudi aija
# er turck vöor iso'realen ende yde * . moor voor 10 : . realen mllén moeten rel'a
#  deycrklaert j ( , 't schip de fwatte moor ; ' capitey n \ tmlliain chegjecnllsn
# ud < n aldaer geauiveert ia } idit de moor en haer niet vér van de stadi vef , o
#  * man , s . pacfcet.x-.vérdoes , j . moor , j.frofer , f.vifch « r , lï.steenhg
#
# --- MOREN in combined corpus ---
# Displaying 10 of 79 matches:
# ceic tydioghe uyt li.arbaryen dat de moren 24000 fierek , '- onlanghs orafl opd
# iieuwë oorfdgs-'preparatien , die de moren maecken , fey t fiïemrditiyöfain ''
#  ; cadix-yet'crocken i 1 o ader ; de moren jonde vervallen , iijn i , dbh '' jf
# tn nóch even leer , '' omdat ' fijne moren en forrific-riënniet « a viljleehtcj
#  adn-jra'-reyten re rrvertertn en op moren » haïe confcentier met dc hoeren hae
# e van 't overlijden van de regerende moren . napoli di romaiiw d-a 3 ïcbxuary .
# echnical image alto metadata artikel moren . accessible ddd:011226011 : mpeg21
# « thomas smit/zifn door , de kapet , moren , men eu tot oftende opgebracht , y
#  algierflè ' kaper opgebracht met 70 moren , welcke verhaelt hekben , dat de al
#  . itvt africa verftaet men , dat de moren la rachc ivel bemachtigt hebben j ma
#
# --- INBOORLING in combined corpus ---
# Displaying 9 of 9 matches:
#  den collonel van rotkirchea , een inboorling defer stad cn altijt dc kroon vran
#  den collonel van rotkirchea , een inboorling defer stad en altijt de kroon vran
# ns gtotyc van dencmarcken een vrye inboorling , van en » gdandt te maecken ; * e
# e fal eyfehen ; dat geen piadus of inboorling verkooren worde ; en dat de elecïi
#  500. uytn\aeckten . ali aga , een inboorling dts laats en goet sol « act » ' wa
# t hjr genaturalifeert is , als een inboorling gdiaadelr . van daer waren de sold
#  geven . 12. het poolfch recht van inboorling , dat aen de saxifche familie gege
# oor reden , dat den bifl'chop geen inboorling van hec rijck en een van defiüfs b
# genomen en herwaerts ovèrgevoert : inboorling van dit eylant , hecfü » et raaer
#
# --- INBOORLINGEN in combined corpus ---
# Displaying 10 of 28 matches:
# rmilfie bekomen , om , ge- wo a 6 inboorlingen , hier te mogen blijven woonen .
# hoeden , wel weder ycmandvan hare inboorlingen tot konirwi mochten kielen , en d
# en gedernouccri i als mede dat de inboorlingen van . ' . 'adagafcar de f ransl-
# nckt , zijn , roor foo `` veel dé inboorlingen aengaet , in waert-gelt aengenomt
# e corrpr-gnk in den oorlog met de inboorlingen v « n't lant te dienen . mt.timoi
# fleten , en fal haer flaet■un met inboorlingen vullen ; f , ifc ' * ' btecnco de
# t foude mogen wereken , ten zv de inboorlingen felf aen 't werek waren . van cam
# n alle -p * paepfche recufinten , inboorlingen ofte-genaturalifccrden , bove « d
# fulks fal fttckken tot nadeel der inboorlingen , waet van'er eengroot gedeelte v
# , alle vremdelingcn , rr.aer geen inboorlingen van defenstaet , hier te mogen la
#
# ================================================================================
# ANALYSIS COMPLETE
# ================================================================================

# %%
import pandas as pd
import nltk
from nltk.text import Text
from nltk.tokenize import word_tokenize
import re
from collections import defaultdict

# Download required NLTK data
nltk.download('punkt', quiet=True)

# Define the target words
target_words = ['moor', 'moren', 'inboorling', 'inboorlingen']

def clean_text(text):
    """Clean and normalize text for better tokenization"""
    if pd.isna(text):
        return ""
    # Remove extra whitespace and normalize
    text = re.sub(r'\s+', ' ', str(text).strip())
    return text

def create_concordance_for_word(word, df):
    """Create NLTK concordance for a specific word"""
    print(f"\n{'='*60}")
    print(f"CONCORDANCE ANALYSIS FOR: {word.upper()}")
    print(f"{'='*60}")
    
    # Filter data for the specific word
    word_data = df[df['word'].str.lower() == word.lower()].copy()
    
    if word_data.empty:
        print(f"No data found for word: {word}")
        return
    
    print(f"Found {len(word_data)} contexts for '{word}'")
    
    # Combine all contexts into one large text
    all_contexts = []
    for context in word_data['context']:
        cleaned_context = clean_text(context)
        if cleaned_context:
            all_contexts.append(cleaned_context)
    
    if not all_contexts:
        print(f"No valid contexts found for '{word}'")
        return
    
    # Join all contexts
    combined_text = ' '.join(all_contexts)
    
    # Tokenize the text
    tokens = word_tokenize(combined_text.lower())
    
    # Create NLTK Text object
    nltk_text = Text(tokens)
    
    # Generate concordance
    print(f"\nConcordance for '{word}' (showing up to 25 lines):")
    print("-" * 80)
    
    try:
        # NLTK concordance
        nltk_text.concordance(word.lower(), lines=25, width=80)
        
        # Additional statistics
        word_count = tokens.count(word.lower())
        total_tokens = len(tokens)
        
        print(f"\nSTATISTICS:")
        print(f"Word frequency: {word_count}")
        print(f"Total tokens in corpus: {total_tokens}")
        print(f"Relative frequency: {word_count/total_tokens:.6f}")
        
        # Year distribution
        if 'year' in word_data.columns:
            year_dist = word_data['year'].value_counts().sort_index()
            print(f"\nYear distribution:")
            for year, count in year_dist.head(10).items():
                print(f"  {year}: {count} occurrences")
    
    except Exception as e:
        print(f"Error generating concordance: {e}")

def analyze_all_words(df, words):
    """Run concordance analysis for all target words"""
    print("NLTK CONCORDANCE ANALYSIS")
    print("=" * 80)
    print(f"Dataset: {len(df)} total contexts")
    print(f"Analyzing words: {', '.join(words)}")
    
    # Summary statistics
    word_counts = {}
    for word in words:
        count = len(df[df['word'].str.lower() == word.lower()])
        word_counts[word] = count
    
    print(f"\nWord frequency summary:")
    for word, count in word_counts.items():
        print(f"  {word}: {count} contexts")
    
    # Generate concordances for each word
    for word in words:
        create_concordance_for_word(word, df)

def create_combined_concordance(df, words):
    """Create a combined concordance for all target words"""
    print(f"\n{'='*60}")
    print("COMBINED CONCORDANCE FOR ALL TARGET WORDS")
    print(f"{'='*60}")
    
    # Filter for all target words
    combined_data = df[df['word'].str.lower().isin([w.lower() for w in words])].copy()
    
    if combined_data.empty:
        print("No data found for any target words")
        return
    
    # Combine all contexts
    all_contexts = []
    for context in combined_data['context']:
        cleaned_context = clean_text(context)
        if cleaned_context:
            all_contexts.append(cleaned_context)
    
    combined_text = ' '.join(all_contexts)
    tokens = word_tokenize(combined_text.lower())
    nltk_text = Text(tokens)
    
    # Show concordance for each word in the combined corpus
    for word in words:
        if word.lower() in tokens:
            print(f"\n--- {word.upper()} in combined corpus ---")
            nltk_text.concordance(word.lower(), lines=10, width=80)

# Main execution
if __name__ == "__main__":
    try:
        # Run individual word analysis
        analyze_all_words(eighteenth_contexts, target_words)
        
        # Run combined analysis
        create_combined_concordance(eighteenth_contexts, target_words)
        
        print(f"\n{'='*80}")
        print("ANALYSIS COMPLETE")
        print(f"{'='*80}")
        
    except Exception as e:
        print(f"Error running analysis: {e}")
        print("Please check your file path and data format.")
# Out:
# NLTK CONCORDANCE ANALYSIS
# ================================================================================
# Dataset: 4218 total contexts
# Analyzing words: moor, moren, inboorling, inboorlingen
#
# Word frequency summary:
#   moor: 2130 contexts
#   moren: 1010 contexts
#   inboorling: 223 contexts
#   inboorlingen: 845 contexts
#
# ============================================================
# CONCORDANCE ANALYSIS FOR: MOOR
# ============================================================
# Found 2130 contexts for 'moor'
#
# Concordance for 'moor' (showing up to 25 lines):
# --------------------------------------------------------------------------------
# Displaying 25 of 2113 matches:
# nd maken . de comier d : c wegens den moor van den martpis p-juavicini , na conf
# eend maken . de comier die wegens den moor van den manpis p^llavicini , na vjonf
# rge ougrerlony van venetien , robbert moor van nnntes , anrhonio da colta ribeir
# cang tuflehen beyde , befloten meteen moor yzet hek ; ftaende ac roorl ' . huyzi
# nzen koning tot prefent onrfingen een moor , van een cxuaordinaiie grootte en wc
# oneerd . alzo jutïr . hubberanet va » moor ik. , jonge aii'bergen op den zoom ,
# . cvd ; -_n ecu va : : blacuvv zilvci moor , met goudwboril i 'goud i.il.-en gev
# en bezacyd , en een van blaeuw zilver moor met gortd geborduiirt , en met goud l
# cn bezaeyt , en een van blacuw silver moor , met goud geborduurt en met goud lak
# en ; een groote deke van blaeu silver moor in goud geborduurd met troplieen en s
# riveerde dc spaenfc c.n-binet-courier moor uyt spanje , en fette .de r ; ys aenl
# nuefe gelant heef : den laciftgcmcltc moor na genua te ruggcfondcn , alwaer hy a
#  , pietcr tonkins van plymouth , elia moor van cartagena , en john price van chc
# len wil , dat de genuefe gefant defen moor weer 11a genua ou de galeven te rug l
# irna , dirk smith van lisbon , samuei moor ver . cuba , pieter smith van zihjaó
#  harmen wijngaert van smirna , samuel moor van cuba , dirck smith van lifiabon ,
# windou ; jacob douwefle snel , marren moor , clacs fokkcs , cn salotnóo pieterlc
# windou ; jacob douwcffe snel , martcn moor , clacs fokkes , cn salomón picterle
# : rrit ides van noortkopping , thomas moor van lo ; > . den ; to : stockholm ( v
# ings van mafllef silvcr en met silver moor bekleed is , fullen tnaendag na fredr
# nden . 's gravenhage den n maert . dr moor die door den heer oliviei minifter de
# ltchop van barcelona had benoemt . de moor die wegens den spaente mitiifter na w
# r , i. ook nog dagelyks den meergem . moor hiet ' te gemoet 2iende , fo dat men
# mt , • is ood * . noch dagelijcks deu moor hier te eraoct llcndcj foo dat min in
#  ectzael behangen .met groen gewiteit moor , flaepkamer , bovrnz.fltj.- , kookcr
#
# STATISTICS:
# Word frequency: 2113
# Total tokens in corpus: 266820
# Relative frequency: 0.007919
#
# Year distribution:
#   1700: 3 occurrences
#   1701: 4 occurrences
#   1702: 5 occurrences
#   1703: 5 occurrences
#   1704: 8 occurrences
#   1705: 9 occurrences
#   1706: 5 occurrences
#   1707: 6 occurrences
#   1708: 8 occurrences
#   1709: 10 occurrences
#
# ============================================================
# CONCORDANCE ANALYSIS FOR: MOREN
# ============================================================
# Found 1010 contexts for 'moren'
#
# Concordance for 'moren' (showing up to 25 lines):
# --------------------------------------------------------------------------------
# Displaying 25 of 742 matches:
# beteooia . hof ns d'andcrc die « och moren volgen , een oytftcl * •■ ) meenden
# adre van den grave de clavijo met de moren aen boord genomen en te cartagcna op
# tt i , * * re goedere » vt het ltndu moren vertrekken , u. eu , het zxlve in de
# tot het reftitueren van alle door de moren genome schepen , infonderheyd . 't s
#  .eitr.ctd . het beviagt was doot.de moren , .oofn van de- k raede liin °°°t «
# etd } zynde de kapiteyn ei . alle de moren te voren aen booid ■ * . * . ? « . ï
# eyn met 4 van fijn matrofen en al de moren te voren aen boord van den gracf ovc
# k met s st. canon , i6baffen , en 80 moren , die liy in 't begin van oftober ge
#  , met de tyding , dat het leger der moren en algerinen dm 2 detes ten getale r
# er dcckt : het is iiker , dat foo dc moren in die plaets gclleven wareu , fy de
# oupen den 19 juny geland zijnde , dc moren den jo dc linker vleugel van hel spa
# e villa herniofa , met tyding dat de moren moren den jo dc linker vleugel van h
# a herniofa , met tyding dat de moren moren den jo dc linker vleugel van hel spa
# e villa herniofa , met tyding dat de moren de stad en de caftcelen van o rui ha
#  in lier goede rtiet . het leger der moren het geen in omtrent .icccc mat tneef
# nfie uyt de ooftzee 3 te viana etich moren van stokholm 3 te kantcs jan diikle
# an den regeerende groot-heitog , ge- moren princefie van saxen-lauenburg , refi
# on had afgcfonden , om lig by andere moren tc voegen ; en het gcrugt liep , dat
# we expeditie op africa , nadcmael de moren fchijnen vaft befloten te hebben , c
#  en gequetft waren . de gencrset dei moren was de gouverneur van oran , een tur
# nifoenen te houden , op du aldus den moren alle juli mocht benomen « vrden , om
# eft , dat de hertog van ripptrda met moren en ren groot : treyn van attiljery i
#  , onder den kolonel merino , om « e moren aen te taften , waer zy ook zyn mogt
# t heeft , dat zyn meefter met 3 sooo moren en een grote treyn van artillery , n
# overwinning die den 30 paftato op dc moren bevogtcn is , en de daet op gevolgde
#
# STATISTICS:
# Word frequency: 742
# Total tokens in corpus: 123506
# Relative frequency: 0.006008
#
# Year distribution:
#   1700: 4 occurrences
#   1701: 4 occurrences
#   1702: 16 occurrences
#   1703: 4 occurrences
#   1704: 9 occurrences
#   1705: 5 occurrences
#   1706: 3 occurrences
#   1707: 5 occurrences
#   1708: 7 occurrences
#   1710: 3 occurrences
#
# ============================================================
# CONCORDANCE ANALYSIS FOR: INBOORLING
# ============================================================
# Found 223 contexts for 'inboorling'
#
# Concordance for 'inboorling' (showing up to 25 lines):
# --------------------------------------------------------------------------------
# Displaying 25 of 226 matches:
# eits-biffchop vaat '' ' ncientoeen inboorling van het coninckrijck tr.oet zijn '
# te werken , op dat defelve als een inboorling foudc geconfidereert werdén . vin
# verhoeds wis dood gedoken dooi eea inboorling , die an ac galey tt rug gekomen w
# yke vréugde over de koiaft van een inboorling die tot 10 een waeidigheyd verheev
# ndboode dzialynski , een pmyliifch inboorling , kanten zig daer tegens aen ; wil
# en schipper ; hy zy vre'emdev : of inboorling deezes lands , zal mógen o'rrderft
# ifter gepardouneert , alfoo hy eeo inboorling van dat land 1s ( , cn gjn vader b
# zyn vader aleiander mat culikanèen inboorling van schotland is geweeft , die ' o
# lyck geantwoord , dat 2y een pools inboorling dat » i toe in het oog hadde ; dae
# ng uyrteiluyten . en een piafte of inboorling , die geene , buytea 't konirigryk
# n om geen andere ko * . mg aan een inboorling te.vetkiezen , zoo als dezelve fno
#  , om dat de aerts . biffchop geen inboorling ca gebote bohemer , maer een wellp
# eert , omdat dc aertsbifïchop geen inboorling en gebote bohemer , miereen wcltph
#  i dat pene an toiiio dellaßizza , inboorling dier stad , aldaarin den ouderdom
# zoo beroemde heer camillo pademi , inboorling deezer hoofd srad , heef door degr
# hop , en den eerw : pater ; ___ï i inboorling deezer stad , tot de cardinaals wa
# el , beyde voor den vreemdeling en inboorling in hunne de stedtr » undtn en mfla
# ezel , beide voor de vreemdelingen inboorling , m hunne wandeling door de steden
# zel , beide voor dc vreemdelinc en inboorling , m hunne wandel 11e door de stede
# neraal der re gujiere clerqiten en inboorling van genua gegeeven . m.n heeft op
# n geleerden heer jacobus j bofcb , inboorling van fleeze siad en kerrogdom . onz
# fenge van c'èmens d « xiii . onzen inboorling meede geweiki heeft , decde ten dj
# n spanjaard it , wyl 't anders een inboorling van sicilien of ten minden een ita
# ne uytvaaiden voor den paus hunnen inboorling gebou den zyn . ook verneemd men d
# noemt heeft , a 's zynde een edele inboorling van deeze stad en staat , dewelke
#
# STATISTICS:
# Word frequency: 226
# Total tokens in corpus: 26315
# Relative frequency: 0.008588
#
# Year distribution:
#   1701: 3 occurrences
#   1703: 1 occurrences
#   1704: 1 occurrences
#   1705: 1 occurrences
#   1712: 1 occurrences
#   1713: 1 occurrences
#   1715: 4 occurrences
#   1717: 1 occurrences
#   1723: 2 occurrences
#   1724: 1 occurrences
#
# ============================================================
# CONCORDANCE ANALYSIS FOR: INBOORLINGEN
# ============================================================
# Found 845 contexts for 'inboorlingen'
#
# Concordance for 'inboorlingen' (showing up to 25 lines):
# --------------------------------------------------------------------------------
# Displaying 25 of 865 matches:
# anchieii tn salviati , * van zyne inboorlingen int sacto collegio . -amfteid.tni
# ren , waer by hy a ! le afwefende inboorlingen voor dé maend mey te rng roept :
# . dat van vyf bilichoppe « , vier inboorlingen van corli , , ca zullen moeten 6.
# s uytgëmüht , wel de vtéemden als inboorlingen hebben1 moeten b'ekcrineri /dat z
# & eert was , dat veel 1000 van de inboorlingen dies landen , ah mede de tapiteyn
# esit was , ' dat veel iooo van de inboorlingen diei landen , alsmede deeapiteyne
# icn , ingeval van verfchil met de inboorlingen , nier gehouden zullen zyn , do_.
#  . ingevalie van veii'chil met dc inboorlingen , niet verpiigt zullen —yn , voor
#  c ' , als meede aan alle `` myne inboorlingen cri on'derdaanen , van wat staat
# menten , bedieningen , & c. , aea inboorlingen ( uilengegeven weiden } dal dc ti
#  , dan in voordeele van 's land * inboorlingen v'dat ' dè * tióu6 , '' « pes ''
# , en zich niet binnen 10 , en der inboorlingen yjdie fcuyjen zyn , welke '' zich
# isdommea ea abdyeo op corfica aea inboorlingen vaa dat eyland fullea gecoofereer
# n vreemdelingen , maar ook aan de inboorlingen des lands op pcene van zeer zwaar
# onr turken en barbaren , dan voor inboorlingen ei » mede-mwoondenn t zodanig w «
# den gezonden , op de vertogen der inboorlingen dar zy in ftaet zyn het zelve wet
#  majt . ; , mogende geene franffe inboorlingen hem aaders dan volftrektclyk koni
# plaats , die tot noch toe en door inboorlingen en door vreemdelingen kan * , gtm
# ten hunne gedachtenis onder hunne inboorlingen vereeu „ wigt . aan ricbelieuis p
# plieden , zo buytenlan „ ders als inboorlingen , diezig tot livorno bevinden , o
# eft de kooplieden fo vreemden als inboorlingen een brief van gemelde prins meede
# an hiet veele duytfe officiers en inboorlingen van deeze landen naat hongaiyea ,
#  ten behoeve van de gra „ nits of inboorlingen van het land , * nevens de commif
# ende , dezelve privilegiën als de inboorlingen zouden hebben ' , vooruamentlyk h
# i'olon en lirhauwen niet dan ac # inboorlingen zouden mogen gegeeven werden . di
#
# STATISTICS:
# Word frequency: 865
# Total tokens in corpus: 100373
# Relative frequency: 0.008618
#
# Year distribution:
#   1700: 2 occurrences
#   1701: 1 occurrences
#   1702: 2 occurrences
#   1703: 4 occurrences
#   1704: 1 occurrences
#   1705: 3 occurrences
#   1706: 2 occurrences
#   1707: 2 occurrences
#   1709: 3 occurrences
#   1711: 3 occurrences
#
# ============================================================
# COMBINED CONCORDANCE FOR ALL TARGET WORDS
# ============================================================
#
# --- MOOR in combined corpus ---
# Displaying 10 of 2114 matches:
# nd maken . de comier d : c wegens den moor van den martpis p-juavicini , na conf
# eend maken . de comier die wegens den moor van den manpis p^llavicini , na vjonf
# rge ougrerlony van venetien , robbert moor van nnntes , anrhonio da colta ribeir
# cang tuflehen beyde , befloten meteen moor yzet hek ; ftaende ac roorl ' . huyzi
# nzen koning tot prefent onrfingen een moor , van een cxuaordinaiie grootte en wc
# oneerd . alzo jutïr . hubberanet va » moor ik. , jonge aii'bergen op den zoom ,
# . cvd ; -_n ecu va : : blacuvv zilvci moor , met goudwboril i 'goud i.il.-en gev
# en bezacyd , en een van blaeuw zilver moor met gortd geborduiirt , en met goud l
# cn bezaeyt , en een van blacuw silver moor , met goud geborduurt en met goud lak
# en ; een groote deke van blaeu silver moor in goud geborduurd met troplieen en s
#
# --- MOREN in combined corpus ---
# Displaying 10 of 743 matches:
# ling van candace , de koninginne deé moren hand . vil a 7. en om dewlke men 't
# beteooia . hof ns d'andcrc die « och moren volgen , een oytftcl * •■ ) meenden
# adre van den grave de clavijo met de moren aen boord genomen en te cartagcna op
# tt i , * * re goedere » vt het ltndu moren vertrekken , u. eu , het zxlve in de
# tot het reftitueren van alle door de moren genome schepen , infonderheyd . 't s
#  .eitr.ctd . het beviagt was doot.de moren , .oofn van de- k raede liin °°°t «
# etd } zynde de kapiteyn ei . alle de moren te voren aen booid ■ * . * . ? « . ï
# eyn met 4 van fijn matrofen en al de moren te voren aen boord van den gracf ovc
# k met s st. canon , i6baffen , en 80 moren , die liy in 't begin van oftober ge
#  , met de tyding , dat het leger der moren en algerinen dm 2 detes ten getale r
#
# --- INBOORLING in combined corpus ---
# Displaying 10 of 228 matches:
# eits-biffchop vaat '' ' ncientoeen inboorling van het coninckrijck tr.oet zijn '
# te werken , op dat defelve als een inboorling foudc geconfidereert werdén . vin
# verhoeds wis dood gedoken dooi eea inboorling , die an ac galey tt rug gekomen w
# yke vréugde over de koiaft van een inboorling die tot 10 een waeidigheyd verheev
# ndboode dzialynski , een pmyliifch inboorling , kanten zig daer tegens aen ; wil
# en schipper ; hy zy vre'emdev : of inboorling deezes lands , zal mógen o'rrderft
# ifter gepardouneert , alfoo hy eeo inboorling van dat land 1s ( , cn gjn vader b
# zyn vader aleiander mat culikanèen inboorling van schotland is geweeft , die ' o
# lyck geantwoord , dat 2y een pools inboorling dat » i toe in het oog hadde ; dae
# ng uyrteiluyten . en een piafte of inboorling , die geene , buytea 't konirigryk
#
# --- INBOORLINGEN in combined corpus ---
# Displaying 10 of 867 matches:
# koninglyke , stsaten , alleen aan inboorlingen word toegeweezen . uit sbagen in
# ullen mogen brengen ten zy ' „ de inboorlingen , meteèri.pispoort : van het mif.
# anchieii tn salviati , * van zyne inboorlingen int sacto collegio . -amfteid.tni
# ren , waer by hy a ! le afwefende inboorlingen voor dé maend mey te rng roept :
# . dat van vyf bilichoppe « , vier inboorlingen van corli , , ca zullen moeten 6.
# s uytgëmüht , wel de vtéemden als inboorlingen hebben1 moeten b'ekcrineri /dat z
# & eert was , dat veel 1000 van de inboorlingen dies landen , ah mede de tapiteyn
# esit was , ' dat veel iooo van de inboorlingen diei landen , alsmede deeapiteyne
# icn , ingeval van verfchil met de inboorlingen , nier gehouden zullen zyn , do_.
#  . ingevalie van veii'chil met dc inboorlingen , niet verpiigt zullen —yn , voor
#
# ================================================================================
# ANALYSIS COMPLETE
# ================================================================================

# %%
import pandas as pd
import nltk
from nltk.text import Text
from nltk.tokenize import word_tokenize
import re
from collections import defaultdict

# Download required NLTK data
nltk.download('punkt', quiet=True)

# Define the target words
target_words = ['moor', 'moren', 'inboorling', 'inboorlingen']

def clean_text(text):
    """Clean and normalize text for better tokenization"""
    if pd.isna(text):
        return ""
    # Remove extra whitespace and normalize
    text = re.sub(r'\s+', ' ', str(text).strip())
    return text

def create_concordance_for_word(word, df):
    """Create NLTK concordance for a specific word"""
    print(f"\n{'='*60}")
    print(f"CONCORDANCE ANALYSIS FOR: {word.upper()}")
    print(f"{'='*60}")
    
    # Filter data for the specific word
    word_data = df[df['word'].str.lower() == word.lower()].copy()
    
    if word_data.empty:
        print(f"No data found for word: {word}")
        return
    
    print(f"Found {len(word_data)} contexts for '{word}'")
    
    # Combine all contexts into one large text
    all_contexts = []
    for context in word_data['context']:
        cleaned_context = clean_text(context)
        if cleaned_context:
            all_contexts.append(cleaned_context)
    
    if not all_contexts:
        print(f"No valid contexts found for '{word}'")
        return
    
    # Join all contexts
    combined_text = ' '.join(all_contexts)
    
    # Tokenize the text
    tokens = word_tokenize(combined_text.lower())
    
    # Create NLTK Text object
    nltk_text = Text(tokens)
    
    # Generate concordance
    print(f"\nConcordance for '{word}' (showing up to 25 lines):")
    print("-" * 80)
    
    try:
        # NLTK concordance
        nltk_text.concordance(word.lower(), lines=25, width=80)
        
        # Additional statistics
        word_count = tokens.count(word.lower())
        total_tokens = len(tokens)
        
        print(f"\nSTATISTICS:")
        print(f"Word frequency: {word_count}")
        print(f"Total tokens in corpus: {total_tokens}")
        print(f"Relative frequency: {word_count/total_tokens:.6f}")
        
        # Year distribution
        if 'year' in word_data.columns:
            year_dist = word_data['year'].value_counts().sort_index()
            print(f"\nYear distribution:")
            for year, count in year_dist.head(10).items():
                print(f"  {year}: {count} occurrences")
    
    except Exception as e:
        print(f"Error generating concordance: {e}")

def analyze_all_words(df, words):
    """Run concordance analysis for all target words"""
    print("NLTK CONCORDANCE ANALYSIS")
    print("=" * 80)
    print(f"Dataset: {len(df)} total contexts")
    print(f"Analyzing words: {', '.join(words)}")
    
    # Summary statistics
    word_counts = {}
    for word in words:
        count = len(df[df['word'].str.lower() == word.lower()])
        word_counts[word] = count
    
    print(f"\nWord frequency summary:")
    for word, count in word_counts.items():
        print(f"  {word}: {count} contexts")
    
    # Generate concordances for each word
    for word in words:
        create_concordance_for_word(word, df)

def create_combined_concordance(df, words):
    """Create a combined concordance for all target words"""
    print(f"\n{'='*60}")
    print("COMBINED CONCORDANCE FOR ALL TARGET WORDS")
    print(f"{'='*60}")
    
    # Filter for all target words
    combined_data = df[df['word'].str.lower().isin([w.lower() for w in words])].copy()
    
    if combined_data.empty:
        print("No data found for any target words")
        return
    
    # Combine all contexts
    all_contexts = []
    for context in combined_data['context']:
        cleaned_context = clean_text(context)
        if cleaned_context:
            all_contexts.append(cleaned_context)
    
    combined_text = ' '.join(all_contexts)
    tokens = word_tokenize(combined_text.lower())
    nltk_text = Text(tokens)
    
    # Show concordance for each word in the combined corpus
    for word in words:
        if word.lower() in tokens:
            print(f"\n--- {word.upper()} in combined corpus ---")
            nltk_text.concordance(word.lower(), lines=10, width=80)

# Main execution
if __name__ == "__main__":
    try:
        # Run individual word analysis
        analyze_all_words(nineteenth_contexts, target_words)
        
        # Run combined analysis
        create_combined_concordance(nineteenth_contexts, target_words)
        
        print(f"\n{'='*80}")
        print("ANALYSIS COMPLETE")
        print(f"{'='*80}")
        
    except Exception as e:
        print(f"Error running analysis: {e}")
        print("Please check your file path and data format.")
# Out:
# NLTK CONCORDANCE ANALYSIS
# ================================================================================
# Dataset: 31167 total contexts
# Analyzing words: moor, moren, inboorling, inboorlingen
#
# Word frequency summary:
#   moor: 11535 contexts
#   moren: 2211 contexts
#   inboorling: 2490 contexts
#   inboorlingen: 14898 contexts
#
# ============================================================
# CONCORDANCE ANALYSIS FOR: MOOR
# ============================================================
# Found 11535 contexts for 'moor'
#
# Concordance for 'moor' (showing up to 25 lines):
# --------------------------------------------------------------------------------
# Displaying 25 of 12168 matches:
# bet inden zich reeds zieken ; i|j nog moor nat weder zullen ook de latere soorte
# itsparen . in elk geval is er nu weer moor kans , dal mot du vvot spoed gemaakt
# et de hoeren van ollefen , veltman en moor de directie van de tooneelisten , die
# as daar , onder bevel tan generaal de moor , opgesteld . prins alexander verliet
# erbevel van den luitenant-generaal dc moor . alvorens het ministerieel hotel te
# an buitenlandsche zaken , generaal de moor en anderen in gevoelvolle bewoordinge
# erbevel van den luitenant-generaal dc moor . alvorens het ministerieel hotel te
# an buitenlandsche zaken , generaal de moor en anderen in gevoelvolle bewoordinge
# everwijk zooveel voordeel bracht . de moor heeft zijne taak vervuld , de moor ma
# de moor heeft zijne taak vervuld , de moor mag heengaan . van de aftredenden mag
# laat partijzucht u nooit verleiden om moor te bewijzen dan gjj kuut , want dan b
# cïoot woord ij , dan weet ik het niet moor . u.igrijp eens , l * zor , de libera
# wikkelt en . aan 't lezeu gaat , is „ moor liciit '' en vooral beter noodig . 't
# 5/32 ko . tot fr 67. reuzel vaster en moor gevraagd ; wilcox dadelnk fr . 84vi a
#  enkele vrienden , benevens de heeren moor , veltman en van 01 -- lefen , uitmak
# er van ollefen voor zich en de heeren moor en veltman een krans op de kist had n
# cri legde namens de heeren veltman en moor een krans op de kist . de heer 11. j.
#  een collectie p l a k plaatjes . zoo moor ; als wij nimmer te voren ontvingen .
# n , inzonderheid diegenen onzer , die moor intiem met ds . van djjk hebben verke
# , geb . roomer , ievent . z . — m. de moor , geb . littooi , z . — a. van hoeve
# n heer frère-orban en den generaal de moor . duizenden waren op de been . havana
# d , geb . koomer , levenl . z.—m . de moor , geb . littooi , z . —a . van hoeve
#  m. haasbroek , jm .. im . — '' w. de moor , man van e. van beek , ' 40 j.'—h .
# . —m . haasbroek , jm . 11 m. —w . de moor , man van e. van beek , 40 j . —h . m
# . patrouille halewrjn , tot opsporing moor : denaar , vond vele geweren en vaatj
#
# STATISTICS:
# Word frequency: 12168
# Total tokens in corpus: 1379001
# Relative frequency: 0.008824
#
# Year distribution:
#   1800: 49 occurrences
#   1801: 42 occurrences
#   1802: 56 occurrences
#   1803: 49 occurrences
#   1804: 32 occurrences
#   1805: 29 occurrences
#   1806: 48 occurrences
#   1807: 34 occurrences
#   1808: 58 occurrences
#   1809: 46 occurrences
#
# ============================================================
# CONCORDANCE ANALYSIS FOR: MOREN
# ============================================================
# Found 2211 contexts for 'moren'
#
# Concordance for 'moren' (showing up to 25 lines):
# --------------------------------------------------------------------------------
# Displaying 25 of 1299 matches:
# pzicht gelukkiger dan de joden en de moren , een middel gevonden om zich in spa
# n dat een dergelijk uiteinde kon bes moren wezen aan een schriftuur , neen aan
# endeel der in dozo provincie gelegen moren en poelen , in verband met verbeteri
# iet kan opwegen . het droogmaken der moren en poelen achten ged . staten ongewe
# teering mode-artikel ! ? . , als : ( moren hoeden , echte en fantasie veeren en
#  sorteering mode-artikelen , als : ( moren hoeden . echte en fantasie veeren en
# alen is onjuist . de heeren martos , moren , montero , rios , de markies van sa
# l ik trachten alle enthousiasme te > moren on als een reporter , neen , als een
#  ter overname aangeboden een zaak in moren en mani'factlren , tegen goede voorw
# w. vnn leeuwen uitkwam . deze gorcis moren , » was p t-.-i it-rit van kcu.nior
# rzoeken dien nen n , ie ' : gewed te moren afhalen , aan % cii w 8 oed onderric
# t gezelschap , met die afschuwelijke moren , worden wij niet weder verlost — da
# traten groote gaten ontstaan , en de moren van vele nnizen splgten en schenres
#  voor de gecombineerde vaart over do moren en kanalen en over don oceaan , tct
# en ƒ .— a .— . 1463 schapen en lam . moren . 311 kunderen , — paarden . sneek ,
# r in ons ongelukkig treurspel , zegt moren , altijd esn koning , dio koning alt
#  a.n » f betuiging aan zoo velen die moren , si l^ h- * rt , hadded ' om u l «
# t ik in mijn zaak heb ondervonden te moren blijven genieten ( 1660 s ' h , nagt
# regroen ' zal « ln een oogwenk om do moren geslingerd worden `` en y en - amste
# randes , ena^enz . ; bekleeding « vn moren . uitsluitend agentschap voor nederl
# . dezen nacht heeft het vrij hard ge moren . wind w `` jbtjk rf'wojwj ; „ mijn
# en ƒ .— a .— . 1143 schapen en lam . moren . 157 runderen , — paarden . snoek ,
# spoorweg staande , goed beklante win moren molen , thans in gebruik bij alb . o
#  het winnen van groni on geld , door moren in provincie » te veranderen en kana
# oeden weg voort te gaan . « onder de moren » is een verhaal in den trant van ju
#
# STATISTICS:
# Word frequency: 1299
# Total tokens in corpus: 271804
# Relative frequency: 0.004779
#
# Year distribution:
#   1800: 47 occurrences
#   1801: 28 occurrences
#   1802: 35 occurrences
#   1803: 44 occurrences
#   1804: 39 occurrences
#   1805: 60 occurrences
#   1806: 27 occurrences
#   1807: 31 occurrences
#   1808: 36 occurrences
#   1809: 34 occurrences
#
# ============================================================
# CONCORDANCE ANALYSIS FOR: INBOORLING
# ============================================================
# Found 2490 contexts for 'inboorling'
#
# Concordance for 'inboorling' (showing up to 25 lines):
# --------------------------------------------------------------------------------
# Displaying 25 of 2734 matches:
# dukt . men zag niet in , waarom de inboorling in deze niet . „ * « elijk staan m
# r antoine monastiek , predikant en inboorling der vaüeijen , vertaald door j. oü
# cht der menigte getrokken door een inboorling in een lang blauw kleed , die met
# oofd is met jan bramsen , mede een inboorling van maasburg , maar die zekeren ka
# ampen aanspreekt en beweert dat de inboorling die onheilen op rekening stelt van
# r den . landraad te palerabang een inboorling van üjambie tot tieo jaar . dwanga
# rna aan de gevolgen overleed , een inboorling van binongko , die onmiddelijk een
#  antoine monastier , predikant len inboorling der vtdleijen , vertaald door j. o
# igheden . bijna altijd telt hijden inboorling zooveel als het slijt onder zijn v
#  behoorende , kunnen het recht van inboorling verkrijgen . par . 2. de aanvragen
# en , de javaan of liever gezegd de inboorling onzer o. i. bezittingen ik wil die
# derling , dat is , ik wil door den inboorling het kapitaal bijeen doen brengen ,
# en , de javaan of liever gezegd de inboorling onzer o. i. bezittingen ik wil die
# derling , dat is , ik wil door den inboorling het kapitaal bijeen doen brengen ,
# ngelschen hadden , zooe j { jl een inboorling van indië om hen ! ig61l v°e ' te
# ij riepen , uit % k • eging > dien inboorling terug . '' ie `` tsch-indische gou
# ngelschen hadden , zooe j { jl een inboorling van indië om hen ! ig61l v°e ' te
# ij riepen , uit % k • eging > dien inboorling terug . '' ie `` tsch-indische gou
# r antoine monastiek , predikant en inboorling der vaueijen , vertaald door j. ou
#  antoine monabtier , predikant e » inboorling der volleyen , vertaald door j. ou
# waardig zouden zijn.het rechfo van inboorling te verkrijgen. , op dit puntzullen
# • eeftsemaaktals door zijn enkelen inboorling , hindoe10 o/mllanistad ' `` niot
# ^f '' gemaaktals door zijn enkelen inboorling , hindoe of^nistan- * niet een spr
#  slechts weinig verwacht , daar de inboorling » bezig zijn om den nieuwen oogsti
# nderhoorigen vermoord zijn . * ken inboorling koopman werd gedood . londen 7 oct
#
# STATISTICS:
# Word frequency: 2734
# Total tokens in corpus: 286805
# Relative frequency: 0.009533
#
# Year distribution:
#   1801: 2 occurrences
#   1802: 5 occurrences
#   1803: 4 occurrences
#   1804: 12 occurrences
#   1805: 7 occurrences
#   1806: 12 occurrences
#   1807: 21 occurrences
#   1808: 11 occurrences
#   1809: 1 occurrences
#   1810: 1 occurrences
#
# ============================================================
# CONCORDANCE ANALYSIS FOR: INBOORLINGEN
# ============================================================
# Found 14898 contexts for 'inboorlingen'
#
# Concordance for 'inboorlingen' (showing up to 25 lines):
# --------------------------------------------------------------------------------
# Displaying 25 of 16665 matches:
# ayetmyo in omvadg toe . negentien inboorlingen zijn er aan overleden . new-york
# emeenzaam gemaakt met de taal der inboorlingen . zijn vroeger zeemansleven hardd
# en voorwerp van vereering is . de inboorlingen van sumatra knielen neer , wannee
#  de troepen ( 2500 blanken en 600 inboorlingen ) waren vol moed en vol vertrouwe
# lking van * * 4 8 'öakpn omst de inboorlingen voor zich heeft doen t^eh^rin te
# schj wb_ jui.f ' plaats maken van inboorlingen voor inimih he , , l ™oet worden
# e heer sheehan , minister voor de inboorlingen , warea tegenwoordig . koning tan
# n het taranaki-distrikt hadden de inboorlingen bezit genomen van de vrije eigend
# en hadden eenige uitwerking op de inboorlingen gehad , en men hoopte , dat bij d
# n het departement voor landen van inboorlingen ( the native landß * court ) o »
# ig aan bet beleid van anderen dan inboorlingen kan worden toevertrouwd . men mag
#  zulk een aanvoerder verkiezen de inboorlingen niot op reis te gaaa . dat waa re
# elf op vertrouweijken voet met de inboorlingen gekomen . dan pas hal hij de inla
# ommen in het gezicht te laten der inboorlingen , wier begeerte daardoor ontvlamd
# elf op vertrouweijken voet met de inboorlingen gekomen . dan pas hal hij de inla
# ommen in het gezicht te laten der inboorlingen , wier begeerte daardoor ontvlamd
# erbeste was , ongewapend onder de inboorlingen te gaan , want- zoodoende won men
# eorten . en wat de wreedheden der inboorlingen betreft , hun moordzucht en bloed
#  blanke ras , in zijn verkeer met inboorlingen , op het geweten heeft , kan blij
# eorten . en wat de wreedheden der inboorlingen betreft , hun moordzucht en bloed
#  blanke ras , in zijn verkeer met inboorlingen , op het geweten heeft , kan blij
# groote kraal verbrand werden . de inboorlingen van de districten in den omtrek v
# groote kraal verbrand werden . de inboorlingen van de districten in den omtrek v
# den minister zelven geheel met de inboorlingen vereenzelvigd , werden in 1818 mo
# emden dezelfde rechten als aan de inboorlingen worden toegekend , zouden de jode
#
# STATISTICS:
# Word frequency: 16665
# Total tokens in corpus: 1693131
# Relative frequency: 0.009843
#
# Year distribution:
#   1800: 25 occurrences
#   1801: 35 occurrences
#   1802: 34 occurrences
#   1803: 30 occurrences
#   1804: 44 occurrences
#   1805: 24 occurrences
#   1806: 32 occurrences
#   1807: 26 occurrences
#   1808: 32 occurrences
#   1809: 15 occurrences
#
# ============================================================
# COMBINED CONCORDANCE FOR ALL TARGET WORDS
# ============================================================
#
# --- MOOR in combined corpus ---
# Displaying 10 of 12185 matches:
# oor altijd daarvan uitgesloten ; geen moor , arabier of jood wordt er in toegela
# oor altijd daarvan uitgesloten ; geen moor , arabier of jood wordt er in toegela
# as , nabij het eiland angua , genomen moor de inboorlingen is er niets 11 i teer
# as , nabij het eiland angua , genomen moor de inboorlingen van solomon , was gez
# orling of vreemdeling . dre . heer de moor tastic ' het gevoelen van den heer do
# werdeti . vier deze * laatsten werden moor len en plunderjn , reeds ? 0 ja-ea vr
# egering . zij koos de hospodaren niet moor , gelijk de privi'egiëa des lands het
# lf en pillen een wel hekend specifiek moor alle deze kwalen , en engelschen , ge
# mijn derde reisgenoot was > e i jonge moor , naar europeesclien trant gekleed en
# as , nabij het eiland angua , genomen moor de inboorlingen van solomon , was gez
#
# --- MOREN in combined corpus ---
# Displaying 10 of 1309 matches:
# den . een groot getal inboorlingen , moren , mozabiten , kabylen en marokanen h
# rs talrijke arrestatiën van voorname moren geschied , welke onder verdenking la
# hen builen de slad zou verslaan , de moren zich mei het vervolgen der zich in d
# van tyi aanboord van liet fj rkschip moren gelokt , om naar qneenslahd overgebr
# om een langdungen oorlog to voeren . moren » . hij is een schatrijk man . zijn
# ylen en arabieren , gedeeltelijk uit moren en negers zamengesteld , en ligging
# er waren , dan die der ajrikaansette moren thans zijn . dat heldere licht , het
# ens , al zijne vrouwen , fin * ven , moren } bedienden , mammelukken , vrienden
# ien 1 gelijk de cutiliinen hadden de moren in eenen . hoogen graad behoefte had
# : . „ de dag is gekomen op welken de moren zich op de christenen wreeken zullen
#
# --- INBOORLING in combined corpus ---
# Displaying 10 of 2872 matches:
# dukt . men zag niet in , waarom de inboorling in deze niet . „ * « elijk staan m
# r antoine monastiek , predikant en inboorling der vaüeijen , vertaald door j. oü
# cht der menigte getrokken door een inboorling in een lang blauw kleed , die met
# oofd is met jan bramsen , mede een inboorling van maasburg , maar die zekeren ka
# ampen aanspreekt en beweert dat de inboorling die onheilen op rekening stelt van
# r den . landraad te palerabang een inboorling van üjambie tot tieo jaar . dwanga
# rna aan de gevolgen overleed , een inboorling van binongko , die onmiddelijk een
#  antoine monastier , predikant len inboorling der vtdleijen , vertaald door j. o
# igheden . bijna altijd telt hijden inboorling zooveel als het slijt onder zijn v
#  behoorende , kunnen het recht van inboorling verkrijgen . par . 2. de aanvragen
#
# --- INBOORLINGEN in combined corpus ---
# Displaying 10 of 16811 matches:
# veel indruk teweeg bragt , dat de inboorlingen over do houding , welke hij bchio
# ee bijna een algemeene drank . de inboorlingen van noord-amerika hebben hun apal
# kolonisten , zoodat europeanen en inboorlingen elkander niet in den weg behoeven
# de , al is het ook |ten koste der inboorlingen . de natuur [ wijst den weg aan t
# dsteren van dronkenschap onder de inboorlingen , hebben wij niet veel dank of da
# al bestaan uit zeven leden ( vier inboorlingen en drie europeanen ) en belast wo
# an zitten , been . '' « dragen de inboorlingen ze bij zich als amuletten , of ho
# unne verkoold been.// //dragen de inboorlingen ze bij zich als amuletten , of ho
#  vastgesteld , volgens hetwelk de inboorlingen zouden opgeroepen en ingedeeld wo
# l water , en men werd ook door de inboorlingen verhinderd om goed op slag te kom
#
# ================================================================================
# ANALYSIS COMPLETE
# ================================================================================

# %%
import pandas as pd
import nltk
from nltk.text import Text
from nltk.tokenize import word_tokenize
import re
from io import StringIO
import sys

# Download required NLTK data if not already present
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt')

# Words to analyze
target_words = ['moor', 'moren', 'inboorling', 'inboorlingen']

def create_concordance_for_word(df, word, context_column='context'):
    """
    Create concordance for a specific word from the dataframe
    """
    # Filter rows that contain the target word (case insensitive)
    word_rows = df[df[context_column].str.contains(word, case=False, na=False)]
    
    if len(word_rows) == 0:
        print(f"No instances of '{word}' found in the data")
        return pd.DataFrame()
    
    # Combine all contexts containing the word
    all_text = ' '.join(word_rows[context_column].fillna('').astype(str))
    
    # Tokenize the text
    tokens = word_tokenize(all_text.lower())
    
    # Create NLTK Text object
    text = Text(tokens)
    
    # Capture concordance output
    old_stdout = sys.stdout
    sys.stdout = mystdout = StringIO()
    
    # Generate concordance (default width is 79, lines is 25)
    text.concordance(word.lower(), width=100, lines=1000)  # Increased width and lines
    
    # Restore stdout and get the output
    sys.stdout = old_stdout
    concordance_output = mystdout.getvalue()
    
    # Parse concordance output into structured data
    concordance_lines = concordance_output.strip().split('\n')
    
    # Remove header and empty lines
    concordance_lines = [line for line in concordance_lines if line.strip() and not line.startswith('Displaying')]
    
    concordance_data = []
    for i, line in enumerate(concordance_lines):
        if line.strip():
            # Split the line to extract left context, keyword, right context
            # NLTK concordance format typically centers the keyword
            parts = line.split()
            if len(parts) > 0:
                # Find the target word in the line (case insensitive)
                line_lower = line.lower()
                word_lower = word.lower()
                
                if word_lower in line_lower:
                    # Find the position of the word
                    word_start = line_lower.find(word_lower)
                    word_end = word_start + len(word_lower)
                    
                    left_context = line[:word_start].strip()
                    keyword = line[word_start:word_end]
                    right_context = line[word_end:].strip()
                    
                    concordance_data.append({
                        'word': word,
                        'line_number': i + 1,
                        'left_context': left_context,
                        'keyword': keyword,
                        'right_context': right_context,
                        'full_line': line.strip()
                    })
    
    return pd.DataFrame(concordance_data)

def create_concordances_for_all_words(df, words):
    """
    Create concordances for all specified words and combine results
    """
    all_concordances = []
    
    for word in words:
        print(f"Processing concordances for: {word}")
        word_concordance = create_concordance_for_word(df, word)
        if not word_concordance.empty:
            all_concordances.append(word_concordance)
            print(f"Found {len(word_concordance)} concordance lines for '{word}'")
        else:
            print(f"No concordances found for '{word}'")
    
    if all_concordances:
        combined_concordances = pd.concat(all_concordances, ignore_index=True)
        return combined_concordances
    else:
        return pd.DataFrame()

# Summary statistics
word_counts = {}
for word in target_words:
    count = len(seventeenth_contexts[seventeenth_contexts['context'].str.contains(word, case=False, na=False)])
    word_counts[word] = count

print(f"\nWord frequency summary:")
for word, count in word_counts.items():
    print(f"  {word}: {count} contexts")

# Generate concordances for all target words
print("Generating concordances...")
concordance_results = create_concordances_for_all_words(seventeenth_contexts, target_words)

# Save results to CSV
if not concordance_results.empty:
    output_file = '/Users/zhujiaqi/Downloads/seventeenth_concordance_results.csv'
    concordance_results.to_csv(output_file, index=False, encoding='utf-8')
    print(f"\nConcordance results saved to: {output_file}")
    print(f"Total concordance lines: {len(concordance_results)}")
    
    # Display summary
    print("\nSummary by word:")
    word_counts = concordance_results['word'].value_counts()
    for word, count in word_counts.items():
        print(f"  {word}: {count} lines")
    
    # Display first few results
    print(f"\nFirst 5 concordance results:")
    print(concordance_results.head())
    
else:
    print("No concordance results found for any of the target words.")

# Alternative approach: Create individual concordance files for each word
print("\n" + "="*50)
print("Creating individual concordance files for each word...")

for word in target_words:
    print(f"\nProcessing individual concordance for: {word}")
    word_concordance = create_concordance_for_word(seventeenth_contexts, word)
    
    if not word_concordance.empty:
        individual_file = f'/Users/zhujiaqi/Downloads/seventeenth_concordance_{word}.csv'
        word_concordance.to_csv(individual_file, index=False, encoding='utf-8')
        print(f"Saved {len(word_concordance)} concordance lines for '{word}' to: {individual_file}")
    else:
        print(f"No concordance lines found for '{word}'")
# Out:
# Word frequency summary:
#   moor: 85 contexts
#   moren: 80 contexts
#   inboorling: 37 contexts
#   inboorlingen: 28 contexts
# Generating concordances...
# Processing concordances for: moor
# Found 76 concordance lines for 'moor'
# Processing concordances for: moren
# Found 79 concordance lines for 'moren'
# Processing concordances for: inboorling
# Found 9 concordance lines for 'inboorling'
# Processing concordances for: inboorlingen
# Found 28 concordance lines for 'inboorlingen'
#
# Concordance results saved to: /Users/zhujiaqi/Downloads/seventeenth_concordance_results.csv
# Total concordance lines: 192
#
# Summary by word:
#   moren: 79 lines
#   moor: 76 lines
#   inboorlingen: 28 lines
#   inboorling: 9 lines
#
# First 5 concordance results:
#    word  line_number                                     left_context keyword  \
# 0  moor            1  t 't schip de locge print , capit , gijsbert de    moor
# 1  moor            2   mift . ' b % lvrr , neaf # 4envar.hen ; ' ; de    moor
# 2  moor            3   het nieuwe oetroy opden 1 o september lactft ,    moor
# 3  moor            4  baftiaenmet de j-uüina.ca'piteyn paflcliie ? de    moor
# 4  moor            5  da jl fcheyete krieken beroof 1 , en vetfeheyde    moor
#
#                                      right_context  \
# 0  , utet geüicke lsdinge '' j « kdea , ca gemonte
# 1   genomen. , » fooal , hy demoor mfende * nen-tn
# 2  hare hoog mog.de heercnsraten ccncracl at de ne
# 3  » lal van daer de poft op madrid « ernen .. ; ,
# 4  jen g jjej1 ! ! voorlede vvoerrfdaeh vettrock h
#
#                                            full_line
# 0  t 't schip de locge print , capit , gijsbert d...
# 1  mift . ' b % lvrr , neaf # 4envar.hen ; ' ; de...
# 2  het nieuwe oetroy opden 1 o september lactft ,...
# 3  baftiaenmet de j-uüina.ca'piteyn paflcliie ? d...
# 4  da jl fcheyete krieken beroof 1 , en vetfeheyd...
#
# ==================================================
# Creating individual concordance files for each word...
#
# Processing individual concordance for: moor
# Saved 76 concordance lines for 'moor' to: /Users/zhujiaqi/Downloads/seventeenth_concordance_moor.csv
#
# Processing individual concordance for: moren
# Saved 79 concordance lines for 'moren' to: /Users/zhujiaqi/Downloads/seventeenth_concordance_moren.csv
#
# Processing individual concordance for: inboorling
# Saved 9 concordance lines for 'inboorling' to: /Users/zhujiaqi/Downloads/seventeenth_concordance_inboorling.csv
#
# Processing individual concordance for: inboorlingen
# Saved 28 concordance lines for 'inboorlingen' to: /Users/zhujiaqi/Downloads/seventeenth_concordance_inboorlingen.csv

# %%
# Words to analyze
target_words = ['moor', 'moren', 'inboorling', 'inboorlingen']

def create_concordance_for_word(df, word, context_column='context'):
    """
    Create concordance for a specific word from the dataframe
    """
    # Filter rows that contain the target word (case insensitive)
    word_rows = df[df[context_column].str.contains(word, case=False, na=False)]
    
    if len(word_rows) == 0:
        print(f"No instances of '{word}' found in the data")
        return pd.DataFrame()
    
    # Combine all contexts containing the word
    all_text = ' '.join(word_rows[context_column].fillna('').astype(str))
    
    # Tokenize the text
    tokens = word_tokenize(all_text.lower())
    
    # Create NLTK Text object
    text = Text(tokens)
    
    # Capture concordance output
    old_stdout = sys.stdout
    sys.stdout = mystdout = StringIO()
    
    # Generate concordance (default width is 79, lines is 25)
    text.concordance(word.lower(), width=100, lines=1000)  # Increased width and lines
    
    # Restore stdout and get the output
    sys.stdout = old_stdout
    concordance_output = mystdout.getvalue()
    
    # Parse concordance output into structured data
    concordance_lines = concordance_output.strip().split('\n')
    
    # Remove header and empty lines
    concordance_lines = [line for line in concordance_lines if line.strip() and not line.startswith('Displaying')]
    
    concordance_data = []
    for i, line in enumerate(concordance_lines):
        if line.strip():
            # Split the line to extract left context, keyword, right context
            # NLTK concordance format typically centers the keyword
            parts = line.split()
            if len(parts) > 0:
                # Find the target word in the line (case insensitive)
                line_lower = line.lower()
                word_lower = word.lower()
                
                if word_lower in line_lower:
                    # Find the position of the word
                    word_start = line_lower.find(word_lower)
                    word_end = word_start + len(word_lower)
                    
                    left_context = line[:word_start].strip()
                    keyword = line[word_start:word_end]
                    right_context = line[word_end:].strip()
                    
                    concordance_data.append({
                        'word': word,
                        'line_number': i + 1,
                        'left_context': left_context,
                        'keyword': keyword,
                        'right_context': right_context,
                        'full_line': line.strip()
                    })
    
    return pd.DataFrame(concordance_data)

def create_concordances_for_all_words(df, words):
    """
    Create concordances for all specified words and combine results
    """
    all_concordances = []
    
    for word in words:
        print(f"Processing concordances for: {word}")
        word_concordance = create_concordance_for_word(df, word)
        if not word_concordance.empty:
            all_concordances.append(word_concordance)
            print(f"Found {len(word_concordance)} concordance lines for '{word}'")
        else:
            print(f"No concordances found for '{word}'")
    
    if all_concordances:
        combined_concordances = pd.concat(all_concordances, ignore_index=True)
        return combined_concordances
    else:
        return pd.DataFrame()

# Summary statistics
word_counts = {}
for word in target_words:
    count = len(eighteenth_contexts[eighteenth_contexts['context'].str.contains(word, case=False, na=False)])
    word_counts[word] = count

print(f"\nWord frequency summary:")
for word, count in word_counts.items():
    print(f"  {word}: {count} contexts")

# Generate concordances for all target words
print("Generating concordances...")
concordance_results = create_concordances_for_all_words(eighteenth_contexts, target_words)

# Save results to CSV
if not concordance_results.empty:
    output_file = '/Users/zhujiaqi/Downloads/eighteenth_concordance_results.csv'
    concordance_results.to_csv(output_file, index=False, encoding='utf-8')
    print(f"\nConcordance results saved to: {output_file}")
    print(f"Total concordance lines: {len(concordance_results)}")
    
    # Display summary
    print("\nSummary by word:")
    word_counts = concordance_results['word'].value_counts()
    for word, count in word_counts.items():
        print(f"  {word}: {count} lines")
    
    # Display first few results
    print(f"\nFirst 5 concordance results:")
    print(concordance_results.head())
    
else:
    print("No concordance results found for any of the target words.")

# Alternative approach: Create individual concordance files for each word
print("\n" + "="*50)
print("Creating individual concordance files for each word...")

for word in target_words:
    print(f"\nProcessing individual concordance for: {word}")
    word_concordance = create_concordance_for_word(eighteenth_contexts, word)
    
    if not word_concordance.empty:
        individual_file = f'/Users/zhujiaqi/Downloads/eighteenth_concordance_{word}.csv'
        word_concordance.to_csv(individual_file, index=False, encoding='utf-8')
        print(f"Saved {len(word_concordance)} concordance lines for '{word}' to: {individual_file}")
    else:
        print(f"No concordance lines found for '{word}'")
# Out:
# Word frequency summary:
#   moor: 2160 contexts
#   moren: 715 contexts
#   inboorling: 1067 contexts
#   inboorlingen: 846 contexts
# Generating concordances...
# Processing concordances for: moor
# Found 1000 concordance lines for 'moor'
# Processing concordances for: moren
# Found 743 concordance lines for 'moren'
# Processing concordances for: inboorling
# Found 228 concordance lines for 'inboorling'
# Processing concordances for: inboorlingen
# Found 867 concordance lines for 'inboorlingen'
#
# Concordance results saved to: /Users/zhujiaqi/Downloads/eighteenth_concordance_results.csv
# Total concordance lines: 2838
#
# Summary by word:
#   moor: 1000 lines
#   inboorlingen: 867 lines
#   moren: 743 lines
#   inboorling: 228 lines
#
# First 5 concordance results:
#    word  line_number                                     left_context keyword  \
# 0  moor            1  lers bel.end maken . de comier d : c wegens den    moor
# 1  moor            2  illürs beleend maken . de comier die wegens den    moor
# 2  moor            3  rerdam.george ougrerlony van venetien , robbert    moor
# 3  moor            4  en bieedc'cang tuflehen beyde , befloten meteen    moor
# 4  moor            5   had vin onzen koning tot prefent onrfingen een    moor
#
#                                      right_context  \
# 0  van den martpis p-juavicini , na conft.iniiiiop
# 1  van den manpis p^llavicini , na vjonftjiitiuo .
# 2  van nnntes , anrhonio da colta ribeiro van stok
# 3  yzet hek ; ftaende ac roorl ' . huyzinge binnen
# 4   , van een cxuaordinaiie grootte en wclgcraaekt
#
#                                            full_line
# 0  lers bel.end maken . de comier d : c wegens de...
# 1  illürs beleend maken . de comier die wegens de...
# 2  rerdam.george ougrerlony van venetien , robber...
# 3  en bieedc'cang tuflehen beyde , befloten metee...
# 4  had vin onzen koning tot prefent onrfingen een...
#
# ==================================================
# Creating individual concordance files for each word...
#
# Processing individual concordance for: moor
# Saved 1000 concordance lines for 'moor' to: /Users/zhujiaqi/Downloads/eighteenth_concordance_moor.csv
#
# Processing individual concordance for: moren
# Saved 743 concordance lines for 'moren' to: /Users/zhujiaqi/Downloads/eighteenth_concordance_moren.csv
#
# Processing individual concordance for: inboorling
# Saved 228 concordance lines for 'inboorling' to: /Users/zhujiaqi/Downloads/eighteenth_concordance_inboorling.csv
#
# Processing individual concordance for: inboorlingen
# Saved 867 concordance lines for 'inboorlingen' to: /Users/zhujiaqi/Downloads/eighteenth_concordance_inboorlingen.csv

# %%
# Words to analyze
target_words = ['moor', 'moren', 'inboorling', 'inboorlingen']

def create_concordance_for_word(df, word, context_column='context'):
    """
    Create concordance for a specific word from the dataframe
    """
    # Filter rows that contain the target word (case insensitive)
    word_rows = df[df[context_column].str.contains(word, case=False, na=False)]
    
    if len(word_rows) == 0:
        print(f"No instances of '{word}' found in the data")
        return pd.DataFrame()
    
    # Combine all contexts containing the word
    all_text = ' '.join(word_rows[context_column].fillna('').astype(str))
    
    # Tokenize the text
    tokens = word_tokenize(all_text.lower())
    
    # Create NLTK Text object
    text = Text(tokens)
    
    # Capture concordance output
    old_stdout = sys.stdout
    sys.stdout = mystdout = StringIO()
    
    # Generate concordance (default width is 79, lines is 25)
    text.concordance(word.lower(), width=100, lines=1000)  # Increased width and lines
    
    # Restore stdout and get the output
    sys.stdout = old_stdout
    concordance_output = mystdout.getvalue()
    
    # Parse concordance output into structured data
    concordance_lines = concordance_output.strip().split('\n')
    
    # Remove header and empty lines
    concordance_lines = [line for line in concordance_lines if line.strip() and not line.startswith('Displaying')]
    
    concordance_data = []
    for i, line in enumerate(concordance_lines):
        if line.strip():
            # Split the line to extract left context, keyword, right context
            # NLTK concordance format typically centers the keyword
            parts = line.split()
            if len(parts) > 0:
                # Find the target word in the line (case insensitive)
                line_lower = line.lower()
                word_lower = word.lower()
                
                if word_lower in line_lower:
                    # Find the position of the word
                    word_start = line_lower.find(word_lower)
                    word_end = word_start + len(word_lower)
                    
                    left_context = line[:word_start].strip()
                    keyword = line[word_start:word_end]
                    right_context = line[word_end:].strip()
                    
                    concordance_data.append({
                        'word': word,
                        'line_number': i + 1,
                        'left_context': left_context,
                        'keyword': keyword,
                        'right_context': right_context,
                        'full_line': line.strip()
                    })
    
    return pd.DataFrame(concordance_data)

def create_concordances_for_all_words(df, words):
    """
    Create concordances for all specified words and combine results
    """
    all_concordances = []
    
    for word in words:
        print(f"Processing concordances for: {word}")
        word_concordance = create_concordance_for_word(df, word)
        if not word_concordance.empty:
            all_concordances.append(word_concordance)
            print(f"Found {len(word_concordance)} concordance lines for '{word}'")
        else:
            print(f"No concordances found for '{word}'")
    
    if all_concordances:
        combined_concordances = pd.concat(all_concordances, ignore_index=True)
        return combined_concordances
    else:
        return pd.DataFrame()

# Summary statistics
word_counts = {}
for word in target_words:
    count = len(nineteenth_contexts[nineteenth_contexts['context'].str.contains(word, case=False, na=False)])
    word_counts[word] = count

print(f"\nWord frequency summary:")
for word, count in word_counts.items():
    print(f"  {word}: {count} contexts")

# Generate concordances for all target words
print("Generating concordances...")
concordance_results = create_concordances_for_all_words(nineteenth_contexts, target_words)

# Save results to CSV
if not concordance_results.empty:
    output_file = '/Users/zhujiaqi/Downloads/nineteenth_concordance_results.csv'
    concordance_results.to_csv(output_file, index=False, encoding='utf-8')
    print(f"\nConcordance results saved to: {output_file}")
    print(f"Total concordance lines: {len(concordance_results)}")
    
    # Display summary
    print("\nSummary by word:")
    word_counts = concordance_results['word'].value_counts()
    for word, count in word_counts.items():
        print(f"  {word}: {count} lines")
    
    # Display first few results
    print(f"\nFirst 5 concordance results:")
    print(concordance_results.head())
    
else:
    print("No concordance results found for any of the target words.")

# Alternative approach: Create individual concordance files for each word
print("\n" + "="*50)
print("Creating individual concordance files for each word...")

for word in target_words:
    print(f"\nProcessing individual concordance for: {word}")
    word_concordance = create_concordance_for_word(nineteenth_contexts, word)
    
    if not word_concordance.empty:
        individual_file = f'/Users/zhujiaqi/Downloads/nineteenth_concordance_{word}.csv'
        word_concordance.to_csv(individual_file, index=False, encoding='utf-8')
        print(f"Saved {len(word_concordance)} concordance lines for '{word}' to: {individual_file}")
    else:
        print(f"No concordance lines found for '{word}'")
# Out:
# Word frequency summary:
#   moor: 12462 contexts
#   moren: 1375 contexts
#   inboorling: 17404 contexts
#   inboorlingen: 15036 contexts
# Generating concordances...
# Processing concordances for: moor
# Found 1000 concordance lines for 'moor'
# Processing concordances for: moren
# Found 1000 concordance lines for 'moren'
# Processing concordances for: inboorling
# Found 1000 concordance lines for 'inboorling'
# Processing concordances for: inboorlingen
# Found 1000 concordance lines for 'inboorlingen'
#
# Concordance results saved to: /Users/zhujiaqi/Downloads/nineteenth_concordance_results.csv
# Total concordance lines: 4000
#
# Summary by word:
#   moor: 1000 lines
#   moren: 1000 lines
#   inboorling: 1000 lines
#   inboorlingen: 1000 lines
#
# First 5 concordance results:
#    word  line_number                                     left_context keyword  \
# 0  moor            1  staat is voor altijd daarvan uitgesloten ; geen    moor
# 1  moor            2  staal is voor altijd daarvan uitgesloten ; geen    moor
# 2  moor            3  n sprake was , nabij het eiland angua , genomen    moor
# 3  moor            4  n sprake was , nabij het eiland angua , genomen    moor
# 4  moor            5  t-zij inboorling of vreemdeling . dre . heer de    moor
#
#                                      right_context  \
# 0   , arabier of jood wordt er in toegelaten . ook
# 1   , arabier of jood wordt er in toegelaten . 0 ,
# 2  de inboorlingen is er niets 11 i teer van de ko
# 3  de inboorlingen van solomon , was gezien en men
# 4  tastic ' het gevoelen van den heer dotrengc aan
#
#                                            full_line
# 0  staat is voor altijd daarvan uitgesloten ; gee...
# 1  staal is voor altijd daarvan uitgesloten ; gee...
# 2  n sprake was , nabij het eiland angua , genome...
# 3  n sprake was , nabij het eiland angua , genome...
# 4  t-zij inboorling of vreemdeling . dre . heer d...
#
# ==================================================
# Creating individual concordance files for each word...
#
# Processing individual concordance for: moor
# Saved 1000 concordance lines for 'moor' to: /Users/zhujiaqi/Downloads/nineteenth_concordance_moor.csv
#
# Processing individual concordance for: moren
# Saved 1000 concordance lines for 'moren' to: /Users/zhujiaqi/Downloads/nineteenth_concordance_moren.csv
#
# Processing individual concordance for: inboorling
# Saved 1000 concordance lines for 'inboorling' to: /Users/zhujiaqi/Downloads/nineteenth_concordance_inboorling.csv
#
# Processing individual concordance for: inboorlingen
# Saved 1000 concordance lines for 'inboorlingen' to: /Users/zhujiaqi/Downloads/nineteenth_concordance_inboorlingen.csv
